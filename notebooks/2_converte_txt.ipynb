# %% [markdown]
# # 2. Converte os arquivos .pdf dos regulamentos em txt.
# - módulo converte_txt.py usa a biblioteca PyMuPDF, importada sob o nome de fitz.
# - o emprego de PyMuPDF pode resultar em erro comum, em que o sistema não reconhece o atributo "open". Nesse caso, é preciso reinstalá-la forçadamente. V. arquivo README.md. por meio do comando pip install --force-reinstall pymupdf

# %%
import sys
sys.path.append('../src')
import os
import converte_txt

# %%
destino = '../data/txt/'
if not os.path.exists(destino):
    # Se não existir, cria o diretório
    os.makedirs(destino)
converte_txt.converter()
# Out:
# Arquivo Aviva IGC ESG IA M FI Mult Cred Priv IE.pdf convertido e gravado na pasta txt.
# Arquivo ITAÚ ESG ENERGIA LIMPA IE FIA IS.pdf convertido e gravado na pasta txt.
# Arquivo SANT ETHICAL AÇÕES SUST SPECIAL IS FC FI.pdf convertido e gravado na pasta txt.
# Arquivo Trend ETF MSCI USA ESG FI de Indice IE.pdf convertido e gravado na pasta txt.
# Arquivo BB AÇÕES EQUIDADE IS FC FI.pdf convertido e gravado na pasta txt.
# Arquivo JGP ESG MASTER FIA IS.pdf convertido e gravado na pasta txt.
# Arquivo BRB INVESTIMENTO SUSTENTÁVEL FIC FIA RESPONSABILIDADE LIMITADA.pdf convertido e gravado na pasta txt.
# Arquivo SICREDI ESG IS FIC FIE MULT.pdf convertido e gravado na pasta txt.
# Arquivo SCHRODER BEST IDEAS ESG FIA IS.pdf convertido e gravado na pasta txt.
# Arquivo BB AÇÕES FX NORD GLOB CLIM ENV IS IE PVT FC.pdf convertido e gravado na pasta txt.
# Arquivo BRAM FIA IS SUST EMPRESARIAL 2.pdf convertido e gravado na pasta txt.
# ...
