# %% [markdown]
# # 1. Coleta de dados
# - Por meio de scraping do sítio virtual da ANBIMA, entre os resultados de pesquisa de fundos ESG.
# - Faz primeiro o scraping dos links das páginas de resultados de pesquisa. Em seguida, acessa cada um dos links, faz o scraping da página respectiva e descarrega o regulamento. Trata os erros numa segunda tentativa, ressaltando a necessidade de o usuário descarregar os regulamentos manualmente. Finalmente, corrige erros de formatação.
#     - Requer instalação de webdriver Chromedriver na variável de ambiente PATH. Mais informações em README.md.
# - Converte arquivos pdf em txt e salva na pasta ..data/txt.

# %% [markdown]
# ## Scraping

# %% [markdown]
# ### Elabora lista de todos os links

# %%
import sys
sys.path.append('../src')
import os
import scraping
links = []
erros = []
encerrados = []
metadados = []
diretorio = '../data/pdf/'
if not os.path.exists(diretorio):
    # Se não existir, cria o diretório
    os.makedirs(diretorio)

# %%
links = scraping.buscar_links('https://data.anbima.com.br/busca/fundos/?q=&page=1&size=100&asg=Sim') # Primeira página de pesquisa - baseada no filtro ASG da Anbima
links2 = scraping.buscar_links('https://data.anbima.com.br/busca/fundos/?q=%22esg%22%20&page=1&size=100&') # Segunda página de pesquisa - baseada na palavra-chave ESG, independente de filtro Anbima
links3 = scraping.buscar_links('https://data.anbima.com.br/busca/fundos/?q=%22esg%22%20&page=2&size=100&') # Terceira página de pesquisa - baseada na palavra-chave ESG, independente de filtro Anbima
links4 = scraping.buscar_links('https://data.anbima.com.br/busca/fundos/?q=%22asg%22%20&page=1&size=50&') # Quarta página de pesquisa - baseada na palavra-chave ASG, independente de filtro Anbima
links5 = scraping.buscar_links('https://data.anbima.com.br/busca/fundos/?q=%22is%22&page=1&size=100&') # Quinta página de pesquisa - baseada na palavra-chave IS, independente de filtro Anbima


total_links = links + links2 + links3 + links4 + links5
total_links = list(set(total_links)) # Eliminar links duplicados
print(f"Total de links pesquisados: {len(total_links)}")
# Out:
# Total de links pesquisados: 201

# %% [markdown]
# ### Descarrega regulamentos

# %%
for indice, link in enumerate(total_links):
    print(f'Processando {indice + 1}/{len(total_links)}. Faltam {len(total_links) - indice - 1}.')
    try:
        # Scraping dos metadados
        data = scraping.scraping_metadados(link)
        if data == False:
            print('Fundo encerrado.')
            encerrados.append(((link, f"Fundo encerrado. Scraping descartado.")))
            continue
        else:
            metadados.append(data)
            safe_name = data["Arquivo"]
            file_path = os.path.join(diretorio, f'{safe_name}.pdf')
            # Verifica se o arquivo já existe antes de tentar baixá-lo
            if not os.path.exists(file_path):
                download_result = scraping.download_regulamento(safe_name, diretorio)
                if not download_result:
                    erros.append((link, "Falha no download. Arquivo não é PDF. Baixar manualmente. Fundo já registrado nos metadados."))
            else:
                print(f'O arquivo {safe_name}.pdf já existe. Download desnecessário.')     
    except Exception as e:
        print(f"Erro inesperado ao processar {link}: {e}")
        erros.append((link, f"Erro inesperado: {e}. Fundo não registrado nos metadados!"))
        
print(f"Processamento concluído. Total de erros: {len(erros)}")
if erros:
    print("Links com erro:")
    for erro in erros:
        print(erro)
# Out:
# Processando 1/201. Faltam 200.
# Regulamento JGP ESG AÇÕES 100 PREV XP SEG FC FIA descarregado.
# Regulamento BRAM FI RF CRED PRIV IS SUSTENTABILIDADE descarregado.
# Processando 122/201. Faltam 79.
# Fundo encerrado.
# Processando 123/201. Faltam 78.
# Regulamento WA FIA BDR ESG Leaders Hedged Nivel I IS descarregado.
# Processando 124/201. Faltam 77.
# Regulamento SULA CRED ASG BB FI FINANCEIRO RF CRED PRIV INVESTIMENTO SUSTENTÁVEL – RESP LIMITADA descarregado.
# Processando 125/201. Faltam 76.
# Regulamento JGP ESG MASTER FIA IS descarregado.
# Processando 126/201. Faltam 75.
# Regulamento BRAD MUL GLO FIX INC ESG USD FI MULT IE descarregado.
# Processando 127/201. Faltam 74.
# Regulamento SCH SUST AÇÕES GLOB USD FC FIA IS IE descarregado.
# Processando 128/201. Faltam 73.
# Fundo encerrado.
# Processando 129/201. Faltam 72.
# Fundo encerrado.
# Processando 130/201. Faltam 71.
# Fundo encerrado.
# Processando 131/201. Faltam 70.
# Regulamento BRASILPREV JGP ESG 100 FC FIA descarregado.
# Processando 132/201. Faltam 69.
# Regulamento ITAÚ MOMENTO ESG AÇÕES FI SUSTENTÁVEL descarregado.
# Processando 133/201. Faltam 68.
# Fundo encerrado.
# Processando 134/201. Faltam 67.
# Regulamento JGP ESG INSTITUCIONAL FC FIA descarregado.
# Processando 135/201. Faltam 66.
# Regulamento RIO BRAVO ESG IS FC INC INF RF CRED PRIV descarregado.
# Processando 136/201. Faltam 65.
# Regulamento JGP ESG PREV XP MASTER FIA IS descarregado.
# Processando 137/201. Faltam 64.
# Fundo encerrado.
# Processando 138/201. Faltam 63.
# Regulamento TAOS ESG FC FI MULT CRED PRIV INVEST SUS descarregado.
# Processando 139/201. Faltam 62.
# Regulamento ITAÚ AÇÕES GLOBAIS ESG IE FC DE IS descarregado.
# Processando 140/201. Faltam 61.
# Regulamento BB AÇÕES BRL PICT GLOB ENV OPP IS IE FI descarregado.
# Processando 141/201. Faltam 60.
# Fundo encerrado.
# Processando 142/201. Faltam 59.
# Regulamento JGP AÇÕES ESG 100 PREV A ICATU S FC FIA descarregado.
# Processando 143/201. Faltam 58.
# Regulamento JGP ESG INST FC DE FIA – FEEDER IX descarregado.
# Processando 144/201. Faltam 57.
# Fundo encerrado.
# Processando 145/201. Faltam 56.
# Regulamento BRB INVESTIMENTO SUSTENTÁVEL FIC FIA RESPONSABILIDADE LIMITADA descarregado.
# Processando 146/201. Faltam 55.
# Regulamento BB MULT LP ASG FC FI descarregado.
# Processando 147/201. Faltam 54.
# Regulamento BRA P E G F I FC FI MULT CRED PRIV P-V descarregado.
# Processando 148/201. Faltam 53.
# Fundo encerrado.
# Processando 149/201. Faltam 52.
# Fundo encerrado.
# Processando 150/201. Faltam 51.
# Regulamento BRAD IS MULT BRL FC FI MULT CRED PRIV IE descarregado.
# Processando 151/201. Faltam 50.
# Fundo encerrado.
# Processando 152/201. Faltam 49.
# Fundo encerrado.
# Processando 153/201. Faltam 48.
# Regulamento SULA CRED INST ESG FI RF CRED PRIV LP IS descarregado.
# Processando 154/201. Faltam 47.
# Regulamento ITAÚ ACTIVE FIX ESG CRED PRIV MULT FI descarregado.
# Processando 155/201. Faltam 46.
# Regulamento SAFRA ESTRATÉGIA ASG FC FIA IS descarregado.
# Processando 187/201. Faltam 14.
# Fundo encerrado.
# Processando 188/201. Faltam 13.
# Regulamento BTG P ESG FI DE INDICE S&P-B3 BR ESG descarregado.
# Processando 189/201. Faltam 12.
# Fundo encerrado.
# Processando 190/201. Faltam 11.
# Fundo encerrado.
# Processando 191/201. Faltam 10.
# Regulamento JGP ESG PREVIDENCIÁRIO MASTER FIA IS descarregado.
# Processando 192/201. Faltam 9.
# Fundo encerrado.
# Processando 193/201. Faltam 8.
# Regulamento BB TOP AÇÕES DIVERSIDADE IS FIA descarregado.
# Processando 194/201. Faltam 7.
# Regulamento ÁGORA P E G F I P-V FC FI MULT CRED PRI descarregado.
# Processando 195/201. Faltam 6.
# Regulamento BNPP INSTI FC DE FUNDOS INC DE INVEST EM INFRA RF SUSTENTÁVEL IS descarregado.
# Processando 196/201. Faltam 5.
# Fundo encerrado.
# Processando 197/201. Faltam 4.
# Fundo encerrado.
# Processando 198/201. Faltam 3.
# Regulamento BB AÇÕES EQUIDADE IS FI descarregado.
# Processando 199/201. Faltam 2.
# Regulamento BB MULTIMERCADO BRL BLACKROCK MULTI-ASSET ESG INVESTIMENTO NO EXTERIOR FUNDO DE INVESTIMENTO FINANCEIRO RESPONSABILIDADE LIMITADA descarregado.
# Processando 200/201. Faltam 1.
# Regulamento ACCESS EQUITY WORLD FIA - IE SUS IS descarregado.
# Processando 201/201. Faltam 0.
# Regulamento ITAÚ INDEX ESG ÁGUA AÇÕES FX IE FC DE IS descarregado.
# Processamento concluído. Total de erros: 6
# Links com erro:
# ('https://data.anbima.com.br/fundos/557374', 'Falha no download. Arquivo não é PDF. Baixar manualmente. Fundo já registrado nos metadados.')
# ('https://data.anbima.com.br/fundos/694274', 'Falha no download. Arquivo não é PDF. Baixar manualmente. Fundo já registrado nos metadados.')
# ('https://data.anbima.com.br/fundos/094579', 'Falha no download. Arquivo não é PDF. Baixar manualmente. Fundo já registrado nos metadados.')
# ('https://data.anbima.com.br/fundos/542202', 'Falha no download. Arquivo não é PDF. Baixar manualmente. Fundo já registrado nos metadados.')
# ('https://data.anbima.com.br/fundos/094684', 'Falha no download. Arquivo não é PDF. Baixar manualmente. Fundo já registrado nos metadados.')
# ('https://data.anbima.com.br/fundos/557277', 'Falha no download. Arquivo não é PDF. Baixar manualmente. Fundo já registrado nos metadados.')

# %% [markdown]
# - observação: descarregar regulamentos listados em erros manualmente mediante pesquisa na internet

# %%
len(metadados) +  len(encerrados) == len(total_links)# Confere se total de metadados corresponde a todos os links pesquisados
# Out:
# True

# %% [markdown]
# ## Corrige problemas no arquivo de metadados
# - O arquivo de metadados tem alguns problemas.
#   1. Em alguns resultados, o botão "Baixar" ficou assinalado como se fosse um valor da tabela de dados disponibilizada pela Anbima. Ele ocupa valores deixados em branco.
#   2. O campo "Última atualização do regulamento" teve o scraping truncado e figura como 'Regulamento\nData de atualização indisponível': 'Baixar'.
#   3. Foi incluído o campo em branco '': ''.
#   4. O valor da cota e a rentabilidade do fundo no ano foram incluídos como valores de um mesmo campo.

# %%
# Corrige problemas iniciais
scraping.problema_1(metadados)
scraping.problema_2(metadados)
scraping.problema_3(metadados)
scraping.problema_4(metadados)

# %%
import random
random.sample(metadados, 15) # Confere integridade da lista
# Out:
# [{'CNPJ': '10.869.591/0001-91',
#   'Código ANBIMA': '237248',
#   'Patrimônio Líquido': 'R$ 58.573.702,27',
#   'Taxa de administração ao ano': '0,80%',
#   'Primeiro aporte': '13/11/2009',
#   'Classe ANBIMA': 'Multimercados',
#   'Tipo ANBIMA': 'Multimercados Balanceados',
#   'Classe CVM': 'Multimercados',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Feeder',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 20 %',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BB ASSET MANAGEMENT',
#   'Gestor': 'BB ASSET MANAGEMENT',
#   'Distribuidor': 'BANCO DO BRASIL',
#   'Custodiante': 'BANCO DO BRASIL',
#   'Controlador de ativos': 'BANCO DO BRASIL',
#   'Controlador de passivos': 'BANCO DO BRASIL',
#   'Taxa de administração máxima ao ano': 'Não se aplica',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'Sim',
#   'Regras da taxa de performance (não padronizada)': 'Será devida taxa de performance de 15% (quinze por cento), combase no resultado do fundo, sobre a rentabilidade que exceder 80% CDI +20%S&P/B3 Brasil ESG, após a dedução de todas as despesas do FUNDO, inclusivetaxa de administração',
#   'Período de cobrança da taxa de performance': '180 Dias',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 0,01',
#   'Aplicação adicional mínima': 'R$ 0,01',
#   'Prazo para emissão de cotas em dias': '1',
#   'Prazo para pagamento do resgate em dias': '4',
#   'Prazo para conversão do resgate em dias': '1',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': '0',
#   'Resgate mínimo': 'R$ 0,01',
#   'Saldo mínimo aplicado': 'R$ 0,01',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/237248',
#   'Fundo': 'BB MULT LP ASG PRIVATE FC FI',
#   'Arquivo': 'BB MULT LP ASG PRIVATE FC FI',
#   'Última atualização': 'n/d',
#   'Valor da cota': '3.319543404',
#   'Rentabilidade 12 meses': 'n/d'},
#  {'CNPJ': '41.837.578/0001-84',
#   'Código ANBIMA': '603791',
#   'Patrimônio Líquido': 'R$ 26.622.820,90',
#   'Taxa de administração ao ano': '0,06%',
#   'Primeiro aporte': '02/08/2021',
#   'Classe ANBIMA': 'Multimercados',
#   'Tipo ANBIMA': 'Multimercados Invest. no Exterior',
#   'Classe CVM': 'Multimercados',
#   'Sub Classe CVM': 'Invest. no Exterior',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 100%',
#   'Credito privado': 'Sim',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Profissional',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Sim',
#   'Aberto estatutariamente': 'Não',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BEM DTVM',
#   'Gestor': 'WRIGHT CAPITAL GESTAO DE RECURSOS',
#   'Distribuidor': 'BEM DTVM',
#   'Custodiante': 'BRADESCO',
#   'Controlador de ativos': 'BRADESCO',
#   'Controlador de passivos': 'BRADESCO',
#   'Taxa de administração máxima ao ano': 'n/d',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': 'n/d',
#   'Prazo para emissão de cotas em dias': '0',
#   'Prazo para pagamento do resgate em dias': '1',
#   'Prazo para conversão do resgate em dias': '0',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/603791',
#   'Fundo': 'WRIGHT IMPACTO II FI MULT CRED PRIV IE IS',
#   'Arquivo': 'WRIGHT IMPACTO II FI MULT CRED PRIV IE IS',
#   'Última atualização': 'n/d',
#   'Valor da cota': '127.8608147',
#   'Rentabilidade 12 meses': '7,53%'},
#  {'CNPJ': '51.681.613/0001-72',
#   'Código ANBIMA': '729639',
#   'Patrimônio Líquido': 'R$ 22.604.703,48',
#   'Taxa de administração ao ano': '0,00%',
#   'Primeiro aporte': '25/09/2023',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Indexados',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Não se Aplica',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BB ASSET MANAGEMENT',
#   'Gestor': 'BB ASSET MANAGEMENT',
#   'Distribuidor': 'BANCO DO BRASIL',
#   'Custodiante': 'BANCO DO BRASIL',
#   'Controlador de ativos': 'BANCO DO BRASIL',
#   'Controlador de passivos': 'BANCO DO BRASIL',
#   'Taxa de administração máxima ao ano': 'Não se aplica',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 0,01',
#   'Aplicação adicional mínima': 'R$ 0,01',
#   'Prazo para emissão de cotas em dias': '0',
#   'Prazo para pagamento do resgate em dias': '2',
#   'Prazo para conversão do resgate em dias': '0',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'R$ 0,01',
#   'Saldo mínimo aplicado': 'R$ 0,01',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/729639',
#   'Fundo': 'BB TOP AÇÕES DIVERSIDADE IS FIA',
#   'Arquivo': 'BB TOP AÇÕES DIVERSIDADE IS FIA',
#   'Última atualização': 'n/d',
#   'Valor da cota': '1.05028164',
#   'Rentabilidade 12 meses': 'n/d'},
#  {'CNPJ': '53.212.784/0001-88',
#   'Código ANBIMA': '741442',
#   'Patrimônio Líquido': 'R$ 51.844.211,66',
#   'Taxa de administração ao ano': '0,20%',
#   'Primeiro aporte': '03/01/2024',
#   'Classe ANBIMA': 'Renda Fixa',
#   'Tipo ANBIMA': 'Renda Fixa Duração Livre Crédito Livre',
#   'Classe CVM': 'Renda Fixa',
#   'Sub Classe CVM': 'Crédito Privado',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'Não se Aplica',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Não se Aplica',
#   'Credito privado': 'Sim',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Profissional',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BRADESCO',
#   'Gestor': 'BRAM BRADESCO ASSET MANAGEMENT SA DTVM',
#   'Distribuidor': 'BRADESCO',
#   'Custodiante': 'BRADESCO',
#   'Controlador de ativos': 'BRADESCO',
#   'Controlador de passivos': 'BRADESCO',
#   'Taxa de administração máxima ao ano': '0,20%',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': 'n/d',
#   'Prazo para emissão de cotas em dias': '0',
#   'Prazo para pagamento do resgate em dias': '20',
#   'Prazo para conversão do resgate em dias': '19',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/741442',
#   'Fundo': 'BRAD FUNDO DE INVESTIMENTO FINANCEIRO RF CRÉD PRIV BAQUARA ESG IS – RESPONSABILIDADE LIMITADA',
#   'Arquivo': 'BRAD FUNDO DE INVESTIMENTO FINANCEIRO RF CRÉD PRIV BAQUARA ESG IS – RESPONSABILIDADE LIMITADA',
#   'Última atualização': 'n/d',
#   'Valor da cota': '1.0510906',
#   'Rentabilidade 12 meses': 'n/d'},
#  {'CNPJ': '10.418.335/0001-88',
#   'Código ANBIMA': '228842',
#   'Patrimônio Líquido': 'R$ 668.902.781,54',
#   'Taxa de administração ao ano': '1,00%',
#   'Primeiro aporte': '10/06/2009',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Indexados',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'IGC-NM',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Não se Aplica',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BB ASSET MANAGEMENT',
#   'Gestor': 'BB ASSET MANAGEMENT',
#   'Distribuidor': 'BANCO DO BRASIL',
#   'Custodiante': 'BANCO DO BRASIL',
#   'Controlador de ativos': 'BANCO DO BRASIL',
#   'Controlador de passivos': 'BANCO DO BRASIL',
#   'Taxa de administração máxima ao ano': 'Não se aplica',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 0,01',
#   'Aplicação adicional mínima': 'R$ 0,01',
#   'Prazo para emissão de cotas em dias': '1',
#   'Prazo para pagamento do resgate em dias': '3',
#   'Prazo para conversão do resgate em dias': '1',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': '0',
#   'Resgate mínimo': 'R$ 0,01',
#   'Saldo mínimo aplicado': 'R$ 0,01',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/228842',
#   'Fundo': 'BB AÇÕES GOVERNANÇA IS FI',
#   'Arquivo': 'BB AÇÕES GOVERNANÇA IS FI',
#   'Última atualização': 'n/d',
#   'Valor da cota': '3.196733871',
#   'Rentabilidade 12 meses': 'n/d'},
#  {'CNPJ': '38.389.079/0001-67',
#   'Código ANBIMA': '557471',
#   'ISIN': 'BR05J4CTF004',
#   'Patrimônio Líquido': 'R$ 11.668.964,31',
#   'Taxa de administração ao ano': 'n/d',
#   'Primeiro aporte': '29/10/2020',
#   'Classe ANBIMA': 'Multimercados',
#   'Tipo ANBIMA': 'Multimercados Invest. no Exterior',
#   'Classe CVM': 'Multimercados',
#   'Sub Classe CVM': 'Invest. no Exterior',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': '> 67%',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Qualificado',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BRADESCO',
#   'Gestor': 'BRAM BRADESCO ASSET MANAGEMENT SA DTVM',
#   'Distribuidor': 'BRADESCO',
#   'Custodiante': 'BRADESCO',
#   'Controlador de ativos': 'BRADESCO',
#   'Controlador de passivos': 'n/d',
#   'Taxa de administração máxima ao ano': 'Percentual',
#   'Unidade da taxa de administração': 'Sim',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'n/d',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'Não se Aplica',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se aplica',
#   'Regra da taxa de saída': 'n/d',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': '1',
#   'Prazo para emissão de cotas em dias': '4',
#   'Prazo para pagamento do resgate em dias': '1',
#   'Prazo para conversão do resgate em dias': 'n/d',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/557471',
#   'Fundo': 'BRAD MUL GLO FIX INC ESG USD FI MULT IE',
#   'Arquivo': 'BRAD MUL GLO FIX INC ESG USD FI MULT IE',
#   'Última atualização': 'n/d',
#   'Valor da cota': '0.8737375',
#   'Rentabilidade 12 meses': '11,39%'},
#  {'CNPJ': '30.530.779/0001-18',
#   'Código ANBIMA': '476226',
#   'Patrimônio Líquido': 'R$ 62.719.684,26',
#   'Taxa de administração ao ano': '1,00%',
#   'Primeiro aporte': '13/09/2018',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Livre',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Feeder',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 20 %',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BB ASSET MANAGEMENT',
#   'Gestor': 'BB ASSET MANAGEMENT',
#   'Distribuidor': 'BANCO DO BRASIL',
#   'Custodiante': 'BANCO DO BRASIL',
#   'Controlador de ativos': 'BANCO DO BRASIL',
#   'Controlador de passivos': 'BANCO DO BRASIL',
#   'Taxa de administração máxima ao ano': '1,50%',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Sim',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': '180 Dias',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 0,01',
#   'Aplicação adicional mínima': 'R$ 0,01',
#   'Prazo para emissão de cotas em dias': '1',
#   'Prazo para pagamento do resgate em dias': '3',
#   'Prazo para conversão do resgate em dias': '1',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'R$ 0,01',
#   'Saldo mínimo aplicado': 'R$ 0,01',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/476226',
#   'Fundo': 'BB AÇÕES EQUIDADE IS FC FI',
#   'Arquivo': 'BB AÇÕES EQUIDADE IS FC FI',
#   'Última atualização': 'n/d',
#   'Valor da cota': '1.285684172',
#   'Rentabilidade 12 meses': 'n/d'},
#  {'CNPJ': '54.875.709/0001-60',
#   'Código ANBIMA': '758175',
#   'Patrimônio Líquido': 'R$ 50.148.585,99',
#   'Taxa de administração ao ano': '0,04%',
#   'Primeiro aporte': '20/05/2024',
#   'Classe ANBIMA': 'Renda Fixa',
#   'Tipo ANBIMA': 'Renda Fixa Duração Livre Grau de Invest.',
#   'Classe CVM': 'Renda Fixa',
#   'Sub Classe CVM': 'Crédito Privado',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Sim',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'Não se Aplica',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Não se Aplica',
#   'Credito privado': 'Sim',
#   'Tipo de investidor': 'Reservado',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Gestor': 'JGP GESTAO DE CREDITO LTDA',
#   'Distribuidor': 'BRE AGENTE AUTONOMO DE INV EIRELI',
#   'Custodiante': 'BNY MELLON BANCO SA',
#   'Controlador de ativos': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Controlador de passivos': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Taxa de administração máxima ao ano': '0,10%',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': 'n/d',
#   'Prazo para emissão de cotas em dias': '0',
#   'Prazo para pagamento do resgate em dias': '1',
#   'Prazo para conversão do resgate em dias': '0',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/758175',
#   'Fundo': 'JGP CORPORATE II FIF IS RF CRED PRIV LP - RESP LIMITADA',
#   'Arquivo': 'JGP CORPORATE II FIF IS RF CRED PRIV LP - RESP LIMITADA',
#   'Última atualização': 'n/d',
#   'Valor da cota': '1.00197173',
#   'Rentabilidade 12 meses': 'n/d'},
#  {'CNPJ': '45.063.916/0001-29',
#   'Código ANBIMA': '675581',
#   'Patrimônio Líquido': 'R$ 4.131.932,97',
#   'Taxa de administração ao ano': '2,00%',
#   'Primeiro aporte': '29/07/2022',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Livre',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Multigestor',
#   'Benchmark': 'IBOVESPA FECHAMENTO',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 20 %',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'SAFRA SERVICOS DE ADMINISTRACAO FIDUCIAR',
#   'Gestor': 'BANCO J SAFRA SA',
#   'Distribuidor': 'BANCO SAFRA S.A',
#   'Custodiante': 'BANCO SAFRA S.A',
#   'Controlador de ativos': 'BANCO SAFRA S.A',
#   'Controlador de passivos': 'n/d',
#   'Taxa de administração máxima ao ano': 'Percentual',
#   'Unidade da taxa de administração': 'Sim',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'A taxa de performance será cobrada com base no resultado de cada aplicação efetuada por cada COTIST',
#   'Regras da taxa de performance (não padronizada)': '180 Dias',
#   'Período de cobrança da taxa de performance': 'Não se Aplica',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se aplica',
#   'Regra da taxa de saída': 'R$ 1.000,00',
#   'Aplicação inicial mínima': 'R$ 1.000,00',
#   'Aplicação adicional mínima': '1',
#   'Prazo para emissão de cotas em dias': '17',
#   'Prazo para pagamento do resgate em dias': '15',
#   'Prazo para conversão do resgate em dias': 'n/d',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'R$ 0,00',
#   'Resgate mínimo': 'R$ 1.000,00',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/675581',
#   'Fundo': 'SAFRA ESTRATÉGIA ASG FC FIA IS',
#   'Arquivo': 'SAFRA ESTRATÉGIA ASG FC FIA IS',
#   'Última atualização': 'n/d',
#   'Valor da cota': '99.522042',
#   'Rentabilidade 12 meses': '1,20%'},
#  {'CNPJ': '35.704.492/0001-80',
#   'Código ANBIMA': '543640',
#   'Patrimônio Líquido': 'R$ 6.949.096,67',
#   'Taxa de administração ao ano': '0,15%',
#   'Primeiro aporte': '09/07/2020',
#   'Tipo de previdência': 'PGBL/VGBL',
#   'Classe ANBIMA': 'Previdência',
#   'Tipo ANBIMA': 'Previdência Ações Ativo',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Sim',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'Não se Aplica',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 40 %',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Profissional',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Não Aplicável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Gestor': 'JGP GESTAO DE RECURSOS LTDA',
#   'Distribuidor': 'JGP GESTAO DE RECURSOS LTDA',
#   'Custodiante': 'BNY MELLON BANCO SA',
#   'Controlador de ativos': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Controlador de passivos': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Taxa de administração máxima ao ano': 'n/d',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': 'n/d',
#   'Prazo para emissão de cotas em dias': '1',
#   'Prazo para pagamento do resgate em dias': '2',
#   'Prazo para conversão do resgate em dias': '0',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/543640',
#   'Fundo': 'JGP ESG PREV XP MASTER FIA IS',
#   'Arquivo': 'JGP ESG PREV XP MASTER FIA IS',
#   'Última atualização': 'n/d',
#   'Valor da cota': '1.00307995',
#   'Rentabilidade 12 meses': 'n/d'},
#  {'CNPJ': '40.022.500/0001-49',
#   'Código ANBIMA': '585882',
#   'Patrimônio Líquido': 'R$ 8.092.030,35',
#   'Taxa de administração ao ano': 'n/d',
#   'Primeiro aporte': '12/04/2021',
#   'Tipo de previdência': 'PGBL/VGBL',
#   'Classe ANBIMA': 'Previdência',
#   'Tipo ANBIMA': 'Previdência Ações Ativo',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Sim',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 40 %',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Reservado',
#   'Característica do investidor': 'Inv. Profissional',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Não Aplicável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BRADESCO',
#   'Gestor': 'BRADESCO',
#   'Distribuidor': 'BRADESCO',
#   'Custodiante': 'BRADESCO',
#   'Controlador de ativos': 'BRADESCO',
#   'Controlador de passivos': 'n/d',
#   'Taxa de administração máxima ao ano': 'Percentual',
#   'Unidade da taxa de administração': 'Sim',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'n/d',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'Não se Aplica',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se aplica',
#   'Regra da taxa de saída': 'n/d',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': '0',
#   'Prazo para emissão de cotas em dias': '3',
#   'Prazo para pagamento do resgate em dias': '1',
#   'Prazo para conversão do resgate em dias': 'n/d',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/585882',
#   'Fundo': 'FIA IS MÁSTER PREVIDÊNCIA ESG',
#   'Arquivo': 'FIA IS MÁSTER PREVIDÊNCIA ESG',
#   'Última atualização': 'n/d',
#   'Valor da cota': '0.8120566',
#   'Rentabilidade 12 meses': '0,81%'},
#  {'CNPJ': '52.580.782/0001-89',
#   'Código ANBIMA': '734357',
#   'Patrimônio Líquido': 'R$ 323.429.673,64',
#   'Taxa de administração ao ano': '0,30%',
#   'Primeiro aporte': '28/11/2023',
#   'Classe ANBIMA': 'Renda Fixa',
#   'Tipo ANBIMA': 'Renda Fixa Duração Livre Grau de Invest.',
#   'Classe CVM': 'Renda Fixa',
#   'Sub Classe CVM': 'Crédito Privado',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'CDI',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Não se Aplica',
#   'Credito privado': 'Sim',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BEM DTVM',
#   'Gestor': 'SUL AMERICA INVESTIMENTOS GESTORA DE REC',
#   'Distribuidor': 'SUL AMERICA INVESTIMENTOS DTVM',
#   'Custodiante': 'BRADESCO',
#   'Controlador de ativos': 'BRADESCO',
#   'Controlador de passivos': 'BRADESCO',
#   'Taxa de administração máxima ao ano': '0,30%',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Sim',
#   'Regras da taxa de performance (não padronizada)': 'acrescido de 0,50% ao ano (“Benchmark”), apurada de acordo com o Parágrafo abaixo, já descontada todas as despesas da Classe, inclusive eventuais valores devidos à Gestora à título de Taxa de Gestão, conforme aplicável.',
#   'Período de cobrança da taxa de performance': '180 Dias',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': 'n/d',
#   'Prazo para emissão de cotas em dias': '0',
#   'Prazo para pagamento do resgate em dias': '15',
#   'Prazo para conversão do resgate em dias': '14',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/734357',
#   'Fundo': 'SULA CRED ASG BB FI FINANCEIRO RF CRED PRIV INVESTIMENTO SUSTENTÁVEL – RESP LIMITADA',
#   'Arquivo': 'SULA CRED ASG BB FI FINANCEIRO RF CRED PRIV INVESTIMENTO SUSTENTÁVEL – RESP LIMITADA',
#   'Última atualização': 'n/d',
#   'Valor da cota': '10.8569803',
#   'Rentabilidade 12 meses': 'n/d'},
#  {'CNPJ': '43.210.575/0001-41',
#   'Código ANBIMA': '658847',
#   'ISIN': 'BR0ARPCTF007',
#   'Patrimônio Líquido': 'R$ 37.922.123,18',
#   'Taxa de administração ao ano': '0,20%',
#   'Primeiro aporte': '30/06/2022',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Invest. no Exterior',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Invest. no Exterior',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'Não se Aplica',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': '> 67%',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Qualificado',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BNP PARIBAS',
#   'Gestor': 'XP ALLOCATION ASSET MANAGEMENT LTDA',
#   'Distribuidor': 'BNP PARIBAS',
#   'Custodiante': 'BNP PARIBAS',
#   'Controlador de ativos': 'BNP PARIBAS',
#   'Controlador de passivos': 'BNP PARIBAS',
#   'Taxa de administração máxima ao ano': 'Não se aplica',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 1.000.000,00',
#   'Aplicação adicional mínima': 'R$ 0,00',
#   'Prazo para emissão de cotas em dias': '1',
#   'Prazo para pagamento do resgate em dias': '6',
#   'Prazo para conversão do resgate em dias': '1',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'R$ 0,00',
#   'Saldo mínimo aplicado': 'R$ 0,00',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/658847',
#   'Fundo': 'Mirova Glob Sust Eqt Dol Adv M FIA IE IS',
#   'Arquivo': 'Mirova Glob Sust Eqt Dol Adv M FIA IE IS',
#   'Última atualização': 'n/d',
#   'Valor da cota': '136.4901023',
#   'Rentabilidade 12 meses': '26,49%'},
#  {'CNPJ': '41.755.418/0001-96',
#   'Código ANBIMA': '613231',
#   'Patrimônio Líquido': 'R$ 1.923.890,89',
#   'Taxa de administração ao ano': 'n/d',
#   'Primeiro aporte': '15/09/2021',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Invest. no Exterior',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Invest. no Exterior',
#   'Fundo ESG': 'Relacionado',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 100%',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Qualificado',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BB ASSET MANAGEMENT',
#   'Gestor': 'BB ASSET MANAGEMENT',
#   'Distribuidor': 'BANCO DO BRASIL',
#   'Custodiante': 'BANCO DO BRASIL',
#   'Controlador de ativos': 'BANCO DO BRASIL',
#   'Controlador de passivos': 'n/d',
#   'Taxa de administração máxima ao ano': 'Percentual',
#   'Unidade da taxa de administração': 'Sim',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'n/d',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'Não se Aplica',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se aplica',
#   'Regra da taxa de saída': 'R$ 1.000,00',
#   'Aplicação inicial mínima': 'R$ 0,01',
#   'Aplicação adicional mínima': '1',
#   'Prazo para emissão de cotas em dias': '5',
#   'Prazo para pagamento do resgate em dias': '1',
#   'Prazo para conversão do resgate em dias': 'n/d',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'R$ 0,01',
#   'Resgate mínimo': 'R$ 1.000,00',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/613231',
#   'Fundo': 'BB ASSET AÇÕES NORDEA GLOBAL DISRUPTION ESG IE FC',
#   'Arquivo': 'BB ASSET AÇÕES NORDEA GLOBAL DISRUPTION ESG IE FC',
#   'Última atualização': 'n/d',
#   'Valor da cota': '0.78316414',
#   'Rentabilidade 12 meses': '18,83%'},
#  {'CNPJ': '39.152.991/0001-63',
#   'Código ANBIMA': '562610',
#   'ISIN': 'BR05WACTF003',
#   'Patrimônio Líquido': 'R$ 160.631.668,66',
#   'Taxa de administração ao ano': '0,00%',
#   'Primeiro aporte': '27/11/2020',
#   'Classe ANBIMA': 'Renda Fixa',
#   'Tipo ANBIMA': 'Renda Fixa Duração Livre Crédito Livre',
#   'Classe CVM': 'Renda Fixa',
#   'Sub Classe CVM': 'Crédito Privado',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Não se Aplica',
#   'Credito privado': 'Sim',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BRADESCO',
#   'Gestor': 'BRAM BRADESCO ASSET MANAGEMENT SA DTVM',
#   'Distribuidor': 'BRADESCO',
#   'Custodiante': 'BRADESCO',
#   'Controlador de ativos': 'BRADESCO',
#   'Controlador de passivos': 'BRADESCO',
#   'Taxa de administração máxima ao ano': 'Não se aplica',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': 'n/d',
#   'Prazo para emissão de cotas em dias': '0',
#   'Prazo para pagamento do resgate em dias': '0',
#   'Prazo para conversão do resgate em dias': '0',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 29/05/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/562610',
#   'Fundo': 'BRAM FI RF CRED PRIV IS SUSTENTABILIDADE',
#   'Arquivo': 'BRAM FI RF CRED PRIV IS SUSTENTABILIDADE',
#   'Última atualização': 'n/d',
#   'Valor da cota': '1.4556716',
#   'Rentabilidade 12 meses': 'n/d'}]

# %%
## Salva metadados em arquivo json. 
import json
with open('../data/json/metadados.json', 'w', encoding='utf-8') as f:
        json.dump(metadados, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Nota. O fundo SAFRA ESTRATÉGIA ASG MASTER II FIA IS foi apagado da lista, por não ter sido possível encontrar manualmente o arquivo de regulamento
