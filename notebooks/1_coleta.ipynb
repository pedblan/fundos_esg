# %% [markdown]
# # 1. Coleta de dados
# - Por meio de scraping do sítio virtual da ANBIMA, entre os resultados de pesquisa de fundos ESG.
# - Faz primeiro o scraping dos links das páginas de resultados de pesquisa. Em seguida, acessa cada um dos links, faz o scraping da página respectiva e descarrega o regulamento. Trata os erros numa segunda tentativa, ressaltando a necessidade de o usuário descarregar os regulamentos manualmente. Finalmente, corrige erros de formatação.
#     - Requer instalação de webdriver Chromedriver na variável de ambiente PATH. Mais informações em README.md.
# - Converte arquivos pdf em txt e salva na pasta ..data/txt.

# %% [markdown]
# ## Scraping

# %% [markdown]
# ### Elabora lista de todos os links

# %%
import sys
sys.path.append('../src')
import os
import scraping
links = []
erros = []
encerrados = []
metadados = []
diretorio = '../data/pdf/'
if not os.path.exists(diretorio):
    # Se não existir, cria o diretório
    os.makedirs(diretorio)

# %%
links = scraping.buscar_links('https://data.anbima.com.br/busca/fundos/?q=&page=1&size=100&asg=Sim') # Primeira página de pesquisa - baseada no filtro ASG da Anbima
links2 = scraping.buscar_links('https://data.anbima.com.br/busca/fundos/?q=%22esg%22%20&page=1&size=100&') # Segunda página de pesquisa - baseada na palavra-chave ESG, independente de filtro Anbima
links3 = scraping.buscar_links('https://data.anbima.com.br/busca/fundos/?q=%22esg%22%20&page=2&size=100&') # Terceira página de pesquisa - baseada na palavra-chave ESG, independente de filtro Anbima
links4 = scraping.buscar_links('https://data.anbima.com.br/busca/fundos/?q=%22asg%22%20&page=1&size=50&') # Quarta página de pesquisa - baseada na palavra-chave ASG, independente de filtro Anbima
links5 = scraping.buscar_links('https://data.anbima.com.br/busca/fundos/?q=%22is%22&page=1&size=100&') # Quinta página de pesquisa - baseada na palavra-chave IS, independente de filtro Anbima


total_links = links + links2 + links3 + links4 + links5
total_links = list(set(total_links)) # Eliminar links duplicados
print(f"Total de links pesquisados: {len(total_links)}")
# Out:
# Total de links pesquisados: 197

# %% [markdown]
# ### Descarrega regulamentos

# %%
for indice, link in enumerate(total_links):
    print(f'Processando {indice + 1}/{len(total_links)}. Faltam {len(total_links) - indice - 1}.')
    try:
        # Scraping dos metadados
        data = scraping.scraping_metadados(link)
        if data == False:
            print('Fundo encerrado.')
            encerrados.append(((link, f"Fundo encerrado. Scraping descartado.")))
            continue
        else:
            metadados.append(data)
            safe_name = data["Arquivo"]
            file_path = os.path.join(diretorio, f'{safe_name}.pdf')
            # Verifica se o arquivo já existe antes de tentar baixá-lo
            if not os.path.exists(file_path):
                download_result = scraping.download_regulamento(safe_name, diretorio)
                if not download_result:
                    erros.append((link, "Falha no download. Arquivo não é PDF. Baixar manualmente. Fundo já registrado nos metadados."))
            else:
                print(f'O arquivo {safe_name}.pdf já existe. Download desnecessário.')     
    except Exception as e:
        print(f"Erro inesperado ao processar {link}: {e}")
        erros.append((link, f"Erro inesperado: {e}. Fundo não registrado nos metadados!"))
        
print(f"Processamento concluído. Total de erros: {len(erros)}")
if erros:
    print("Links com erro:")
    for erro in erros:
        print(erro)
# Out:
# Processando 1/197. Faltam 196.
# Processando 183/197. Faltam 14.
# O arquivo JGP ESG INSTITUCIONAL FC FIA.pdf já existe. Download desnecessário.
# Processando 184/197. Faltam 13.
# O arquivo Mirova Glob Sust Eqt Dol Adv M FIA IE IS.pdf já existe. Download desnecessário.
# Processando 185/197. Faltam 12.
# Fundo encerrado.
# Processando 186/197. Faltam 11.
# O arquivo JGP AÇÕES ESG 100 PREV ICATU SEG FC FIA.pdf já existe. Download desnecessário.
# Processando 187/197. Faltam 10.
# Fundo encerrado.
# Processando 188/197. Faltam 9.
# Fundo encerrado.
# Processando 189/197. Faltam 8.
# Fundo encerrado.
# Processando 190/197. Faltam 7.
# O arquivo ITAÚ ESG ENERGIA LIMPA IE FIA IS.pdf já existe. Download desnecessário.
# Processando 191/197. Faltam 6.
# O arquivo Trend ETF MSCI Em Mkts ESG FI Indice IE.pdf já existe. Download desnecessário.
# Processando 192/197. Faltam 5.
# O arquivo BRAM FIA IS SUST EMPRESARIAL 2.pdf já existe. Download desnecessário.
# Processando 193/197. Faltam 4.
# O arquivo BRADESCO H FI DE AÇÕES IS SRI.pdf já existe. Download desnecessário.
# Processando 194/197. Faltam 3.
# O arquivo ÁGORA P E G F I P-V FC FI MULT CRED PRI.pdf já existe. Download desnecessário.
# Processando 195/197. Faltam 2.
# O arquivo Trend ETF MSCI EAFE ESG FI de Indice IE.pdf já existe. Download desnecessário.
# Processando 196/197. Faltam 1.
# O arquivo ITAÚ MOMENTO ESG AÇÕES FC IS.pdf já existe. Download desnecessário.
# Processando 197/197. Faltam 0.
# Fundo encerrado.
# Processamento concluído. Total de erros: 0

# %% [markdown]
# - observação: descarregar regulamentos listados em erros manualmente mediante pesquisa na internet

# %%
len(metadados) +  len(encerrados) == len(total_links)# Confere se total de metadados corresponde a todos os links pesquisados
# Out:
# True

# %% [markdown]
# ## Corrige problemas no arquivo de metadados
# - O arquivo de metadados tem alguns problemas.
#   1. Em alguns resultados, o botão "Baixar" ficou assinalado como se fosse um valor da tabela de dados disponibilizada pela Anbima. Ele ocupa valores deixados em branco.
#   2. O campo "Última atualização do regulamento" teve o scraping truncado e figura como 'Regulamento\nData de atualização indisponível': 'Baixar'.
#   3. Foi incluído o campo em branco '': ''.
#   4. O valor da cota e a rentabilidade do fundo no ano foram incluídos como valores de um mesmo campo.

# %%
# Corrige problemas iniciais
scraping.problema_1(metadados)
scraping.problema_2(metadados)
scraping.problema_3(metadados)
scraping.problema_4(metadados)

# %%
import random
random.sample(metadados, 15) # Confere integridade da lista
# Out:
# [{'CNPJ': '39.490.897/0001-14',
#   'Código ANBIMA': '568295',
#   'ISIN': 'BR065RCTF004',
#   'Patrimônio Líquido': 'R$ 12.277.523,16',
#   'Taxa de administração ao ano': '0,80%',
#   'Primeiro aporte': '09/12/2020',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Invest. no Exterior',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Invest. no Exterior',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Feeder',
#   'Benchmark': 'Não se Aplica',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': '> 67%',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Qualificado',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'ITAU UNIBANCO SA',
#   'Gestor': 'ITAU UNIBANCO ASSET MANAGEMENT LTDA',
#   'Distribuidor': 'ITAU UNIBANCO SA',
#   'Custodiante': 'ITAU UNIBANCO SA',
#   'Controlador de ativos': 'ITAU UNIBANCO SA',
#   'Controlador de passivos': 'ITAU UNIBANCO SA',
#   'Taxa de administração máxima ao ano': '0,80%',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 1,00',
#   'Aplicação adicional mínima': 'R$ 1,00',
#   'Prazo para emissão de cotas em dias': '1',
#   'Prazo para pagamento do resgate em dias': '4',
#   'Prazo para conversão do resgate em dias': '1',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'R$ 1,00',
#   'Saldo mínimo aplicado': 'R$ 1,00',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/568295',
#   'Fundo': 'ITAÚ INDEX ESG ÁGUA AÇÕES FX IE FC DE IS',
#   'Arquivo': 'ITAÚ INDEX ESG ÁGUA AÇÕES FX IE FC DE IS',
#   'Última atualização': 'n/d',
#   'Valor da cota': '11.939951',
#   'Rentabilidade 12 meses': '8,88%'},
#  {'CNPJ': '11.052.415/0001-25',
#   'Código ANBIMA': '235431',
#   'Patrimônio Líquido': 'R$ 176.144.450,81',
#   'Taxa de administração ao ano': '0,00%',
#   'Primeiro aporte': '02/10/2009',
#   'Classe ANBIMA': 'Multimercados',
#   'Tipo ANBIMA': 'Multimercados Balanceados',
#   'Classe CVM': 'Multimercados',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'CDI',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 20 %',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BB ASSET MANAGEMENT',
#   'Gestor': 'BB ASSET MANAGEMENT',
#   'Distribuidor': 'BANCO DO BRASIL',
#   'Custodiante': 'BANCO DO BRASIL',
#   'Controlador de ativos': 'BANCO DO BRASIL',
#   'Controlador de passivos': 'BANCO DO BRASIL',
#   'Taxa de administração máxima ao ano': 'Não se aplica',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 0,01',
#   'Aplicação adicional mínima': 'R$ 0,01',
#   'Prazo para emissão de cotas em dias': '1',
#   'Prazo para pagamento do resgate em dias': '4',
#   'Prazo para conversão do resgate em dias': '1',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': '0',
#   'Resgate mínimo': 'R$ 0,01',
#   'Saldo mínimo aplicado': 'R$ 0,01',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/235431',
#   'Fundo': 'BB TOP MULT ASG FI LP',
#   'Arquivo': 'BB TOP MULT ASG FI LP',
#   'Última atualização': 'n/d',
#   'Valor da cota': '3.79866865',
#   'Rentabilidade 12 meses': '16,40%'},
#  {'CNPJ': '41.755.464/0001-95',
#   'Código ANBIMA': '624217',
#   'Patrimônio Líquido': 'R$ 10.918.485,37',
#   'Taxa de administração ao ano': '0,80%',
#   'Primeiro aporte': '26/11/2021',
#   'Tipo de previdência': 'PGBL/VGBL',
#   'Classe ANBIMA': 'Previdência',
#   'Tipo ANBIMA': 'Previdência Multimercado Livre',
#   'Classe CVM': 'Multimercados',
#   'Sub Classe CVM': 'Crédito Privado',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 20 %',
#   'Credito privado': 'Sim',
#   'Tipo de investidor': 'Exclusivo',
#   'Característica do investidor': 'Inv. Profissional',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Não Aplicável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BRADESCO',
#   'Gestor': 'BRADESCO',
#   'Distribuidor': 'BRADESCO',
#   'Custodiante': 'BRADESCO',
#   'Controlador de ativos': 'BRADESCO',
#   'Controlador de passivos': 'n/d',
#   'Taxa de administração máxima ao ano': 'Percentual',
#   'Unidade da taxa de administração': 'Sim',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'n/d',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'Não se Aplica',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se aplica',
#   'Regra da taxa de saída': 'n/d',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': '0',
#   'Prazo para emissão de cotas em dias': '5',
#   'Prazo para pagamento do resgate em dias': '1',
#   'Prazo para conversão do resgate em dias': 'n/d',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/624217',
#   'Fundo': 'ÁGORA P E G F I P/V FC FI MULT CRED PRI',
#   'Arquivo': 'ÁGORA P E G F I P-V FC FI MULT CRED PRI',
#   'Última atualização': 'n/d',
#   'Valor da cota': '1.2286286',
#   'Rentabilidade 12 meses': '11,76%'},
#  {'CNPJ': '42.730.970/0001-92',
#   'Código ANBIMA': '613657',
#   'Patrimônio Líquido': 'R$ 51.131.610,81',
#   'Taxa de administração ao ano': '0,50%',
#   'Primeiro aporte': '17/09/2021',
#   'Classe ANBIMA': 'Renda Fixa',
#   'Tipo ANBIMA': 'Renda Fixa Duração Livre Crédito Livre',
#   'Classe CVM': 'Renda Fixa',
#   'Sub Classe CVM': 'Longo Prazo',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'Não se Aplica',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Não se Aplica',
#   'Credito privado': 'Sim',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Qualificado',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BTG PACTUAL SERVICOS FINANCEIROS SA DTVM',
#   'Gestor': 'BTG PACTUAL',
#   'Distribuidor': 'BANCO BTG PACTUAL SA',
#   'Custodiante': 'BANCO BTG PACTUAL SA',
#   'Controlador de ativos': 'BTG PACTUAL SERVICOS FINANCEIROS SA DTVM',
#   'Controlador de passivos': 'BTG PACTUAL SERVICOS FINANCEIROS SA DTVM',
#   'Taxa de administração máxima ao ano': 'Não se aplica',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'Sim',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': '180 Dias',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 5.000,00',
#   'Aplicação adicional mínima': 'R$ 1.000,00',
#   'Prazo para emissão de cotas em dias': '1',
#   'Prazo para pagamento do resgate em dias': '31',
#   'Prazo para conversão do resgate em dias': '30',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'R$ 1.000,00',
#   'Saldo mínimo aplicado': 'R$ 1.000,00',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/613657',
#   'Fundo': 'BT P CRED CORP ESG FI RF IS CRED PRIV LP',
#   'Arquivo': 'BT P CRED CORP ESG FI RF IS CRED PRIV LP',
#   'Última atualização': 'n/d',
#   'Valor da cota': '1.381021',
#   'Rentabilidade 12 meses': '15,13%'},
#  {'CNPJ': '12.107.669/0001-66',
#   'Código ANBIMA': '305626',
#   'ISIN': 'BRMAS6CTF005',
#   'Patrimônio Líquido': 'R$ 2.081.158.390,59',
#   'Taxa de administração ao ano': '0,02%',
#   'Primeiro aporte': '08/06/2012',
#   'Classe ANBIMA': 'Renda Fixa',
#   'Tipo ANBIMA': 'Renda Fixa Duração Baixa Grau de Invest.',
#   'Classe CVM': 'Renda Fixa',
#   'Sub Classe CVM': 'Crédito Privado',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'Não se Aplica',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Não se Aplica',
#   'Credito privado': 'Sim',
#   'Tipo de investidor': 'Reservado',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BNP PARIBAS',
#   'Gestor': 'BNP PARIBAS ASSET',
#   'Distribuidor': 'BNP PARIBAS',
#   'Custodiante': 'BNP PARIBAS',
#   'Controlador de ativos': 'BNP PARIBAS',
#   'Controlador de passivos': 'BNP PARIBAS',
#   'Taxa de administração máxima ao ano': 'Não se aplica',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': 'n/d',
#   'Prazo para emissão de cotas em dias': '0',
#   'Prazo para pagamento do resgate em dias': '1',
#   'Prazo para conversão do resgate em dias': '0',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': '0',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/305626',
#   'Fundo': 'BNPP M.CRED FI RF CRED PRIV LP SUST IS',
#   'Arquivo': 'BNPP M.CRED FI RF CRED PRIV LP SUST IS',
#   'Última atualização': 'n/d',
#   'Valor da cota': '303.0566431',
#   'Rentabilidade 12 meses': '14,19%'},
#  {'CNPJ': '42.619.342/0001-34',
#   'Código ANBIMA': '648663',
#   'Patrimônio Líquido': 'R$ 33.652.686,26',
#   'Taxa de administração ao ano': '2,00%',
#   'Primeiro aporte': '07/04/2022',
#   'Tipo de previdência': 'PGBL/VGBL',
#   'Classe ANBIMA': 'Previdência',
#   'Tipo ANBIMA': 'Previdência Ações Ativo',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Sim',
#   'Estrutura de gestão': 'Espelho',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 40 %',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Reservado',
#   'Característica do investidor': 'Inv. Profissional',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Não Aplicável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BB ASSET MANAGEMENT',
#   'Gestor': 'BB ASSET MANAGEMENT',
#   'Distribuidor': 'BANCO DO BRASIL',
#   'Custodiante': 'BANCO DO BRASIL',
#   'Controlador de ativos': 'BANCO DO BRASIL',
#   'Controlador de passivos': 'n/d',
#   'Taxa de administração máxima ao ano': 'Percentual',
#   'Unidade da taxa de administração': 'Sim',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'n/d',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'Não se Aplica',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se aplica',
#   'Regra da taxa de saída': 'n/d',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': '0',
#   'Prazo para emissão de cotas em dias': '4',
#   'Prazo para pagamento do resgate em dias': '2',
#   'Prazo para conversão do resgate em dias': 'n/d',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/648663',
#   'Fundo': 'BRASILPREV TOP EST JGP ESG 100 FC FIA',
#   'Arquivo': 'BRASILPREV TOP EST JGP ESG 100 FC FIA',
#   'Última atualização': 'n/d',
#   'Valor da cota': '1.038716',
#   'Rentabilidade 12 meses': '24,01%'},
#  {'CNPJ': '41.755.394/0001-75',
#   'Código ANBIMA': '613630',
#   'Patrimônio Líquido': 'R$ 13.656.178,09',
#   'Taxa de administração ao ano': '0,50%',
#   'Primeiro aporte': '22/09/2021',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Invest. no Exterior',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Invest. no Exterior',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': '> 67%',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Qualificado',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BB ASSET MANAGEMENT',
#   'Gestor': 'BB ASSET MANAGEMENT',
#   'Distribuidor': 'BANCO DO BRASIL',
#   'Custodiante': 'BANCO DO BRASIL',
#   'Controlador de ativos': 'BANCO DO BRASIL',
#   'Controlador de passivos': 'BANCO DO BRASIL',
#   'Taxa de administração máxima ao ano': 'n/d',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 1.000,00',
#   'Aplicação adicional mínima': 'R$ 0,01',
#   'Prazo para emissão de cotas em dias': '1',
#   'Prazo para pagamento do resgate em dias': '5',
#   'Prazo para conversão do resgate em dias': '1',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'R$ 0,01',
#   'Saldo mínimo aplicado': 'R$ 1.000,00',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/613630',
#   'Fundo': 'BB AÇÕES FX NORD GLOB DIS ESG PVT IE FC',
#   'Arquivo': 'BB AÇÕES FX NORD GLOB DIS ESG PVT IE FC',
#   'Última atualização': 'n/d',
#   'Valor da cota': '0.751262359',
#   'Rentabilidade 12 meses': '11,83%'},
#  {'CNPJ': '39.723.229/0001-90',
#   'Código ANBIMA': '594563',
#   'ISIN': 'BR07AECTF007',
#   'Patrimônio Líquido': 'R$ 136.523.852,62',
#   'Taxa de administração ao ano': '0,07%',
#   'Primeiro aporte': '10/03/2021',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Invest. no Exterior',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Invest. no Exterior',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FI',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'Não se Aplica',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': '> 67%',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Qualificado',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BNP PARIBAS',
#   'Gestor': 'BLACKROCK BRASIL GESTORA DE INVESTIMENTO',
#   'Distribuidor': 'BNP PARIBAS',
#   'Custodiante': 'BNP PARIBAS',
#   'Controlador de ativos': 'BNP PARIBAS',
#   'Controlador de passivos': 'BNP PARIBAS',
#   'Taxa de administração máxima ao ano': 'Não se aplica',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 1.000.000,00',
#   'Aplicação adicional mínima': 'R$ 5.000,00',
#   'Prazo para emissão de cotas em dias': '2',
#   'Prazo para pagamento do resgate em dias': '7',
#   'Prazo para conversão do resgate em dias': '2',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'R$ 5.000,00',
#   'Saldo mínimo aplicado': 'R$ 500.000,00',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/594563',
#   'Fundo': 'Blackrock FIA Globais ESG IE',
#   'Arquivo': 'Blackrock FIA Globais ESG IE',
#   'Última atualização': 'n/d',
#   'Valor da cota': '114.7464455',
#   'Rentabilidade 12 meses': '24,17%'},
#  {'CNPJ': '37.802.039/0001-32',
#   'Código ANBIMA': '552666',
#   'ISIN': 'BR051HCTF005',
#   'Patrimônio Líquido': 'R$ 16.549.277,70',
#   'Taxa de administração ao ano': '2,00%',
#   'Primeiro aporte': '31/08/2020',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Livre',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Feeder',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 40 %',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Qualificado',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Sim',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'ITAU UNIBANCO SA',
#   'Gestor': 'ITAU UNIBANCO ASSET MANAGEMENT LTDA',
#   'Distribuidor': 'ITAU UNIBANCO SA',
#   'Custodiante': 'ITAU UNIBANCO SA',
#   'Controlador de ativos': 'ITAU UNIBANCO SA',
#   'Controlador de passivos': 'ITAU UNIBANCO SA',
#   'Taxa de administração máxima ao ano': '2,00%',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Sim',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': '180 Dias',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 1,00',
#   'Aplicação adicional mínima': 'R$ 1,00',
#   'Prazo para emissão de cotas em dias': '0',
#   'Prazo para pagamento do resgate em dias': '23',
#   'Prazo para conversão do resgate em dias': '21',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'R$ 1,00',
#   'Saldo mínimo aplicado': 'R$ 1,00',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/552666',
#   'Fundo': 'ITAÚ MOMENTO ESG AÇÕES FC IS',
#   'Arquivo': 'ITAÚ MOMENTO ESG AÇÕES FC IS',
#   'Última atualização': 'n/d',
#   'Valor da cota': '7.578897',
#   'Rentabilidade 12 meses': '11,71%'},
#  {'CNPJ': '36.352.690/0001-95',
#   'Código ANBIMA': '546364',
#   'Patrimônio Líquido': 'R$ 6.430.199,86',
#   'Taxa de administração ao ano': '2,25%',
#   'Primeiro aporte': '31/07/2020',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Livre',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Feeder',
#   'Benchmark': 'Não se Aplica',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 20 %',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Gestor': 'JGP GESTAO DE RECURSOS LTDA',
#   'Distribuidor': 'BNY MELLON BANCO SA',
#   'Custodiante': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Controlador de ativos': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Controlador de passivos': 'n/d',
#   'Taxa de administração máxima ao ano': 'Percentual',
#   'Unidade da taxa de administração': 'Sim',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'n/d',
#   'Regras da taxa de performance (não padronizada)': '360 Dias',
#   'Período de cobrança da taxa de performance': 'Não se Aplica',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se aplica',
#   'Regra da taxa de saída': 'R$ 100.000,00',
#   'Aplicação inicial mínima': 'R$ 50.000,00',
#   'Aplicação adicional mínima': '1',
#   'Prazo para emissão de cotas em dias': '32',
#   'Prazo para pagamento do resgate em dias': '30',
#   'Prazo para conversão do resgate em dias': 'n/d',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'R$ 50.000,00',
#   'Resgate mínimo': 'R$ 100.000,00',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/546364',
#   'Fundo': 'JGP ESG INST ADV FC FIA',
#   'Arquivo': 'JGP ESG INST ADV FC FIA',
#   'Última atualização': 'n/d',
#   'Valor da cota': '96.67179356',
#   'Rentabilidade 12 meses': '22,31%'},
#  {'CNPJ': '35.408.329/0001-70',
#   'Código ANBIMA': '520901',
#   'Patrimônio Líquido': 'R$ 297.401.709,82',
#   'Taxa de administração ao ano': '0,50%',
#   'Primeiro aporte': '27/12/2019',
#   'Classe ANBIMA': 'Renda Fixa',
#   'Tipo ANBIMA': 'Renda Fixa Duração Baixa Grau de Invest.',
#   'Classe CVM': 'Renda Fixa',
#   'Sub Classe CVM': 'Longo Prazo',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Feeder',
#   'Benchmark': 'CDI',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 20 %',
#   'Credito privado': 'Sim',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Gestor': 'CG INVESTIMENTOS BRAZIL LTDA',
#   'Distribuidor': 'BNY MELLON BANCO SA',
#   'Custodiante': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Controlador de ativos': 'BNY MELLON SERVICOS FINANCEIROS DTVM SA',
#   'Controlador de passivos': 'n/d',
#   'Taxa de administração máxima ao ano': 'Percentual',
#   'Unidade da taxa de administração': 'Sim',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'n/d',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'Não se Aplica',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se aplica',
#   'Regra da taxa de saída': 'R$ 500,00',
#   'Aplicação inicial mínima': 'R$ 500,00',
#   'Aplicação adicional mínima': '0',
#   'Prazo para emissão de cotas em dias': '1',
#   'Prazo para pagamento do resgate em dias': '0',
#   'Prazo para conversão do resgate em dias': 'n/d',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'R$ 500,00',
#   'Resgate mínimo': 'R$ 0,00',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/520901',
#   'Fundo': 'COMPASS ESG C S FC FI RF CRED PRIV LP',
#   'Arquivo': 'COMPASS ESG C S FC FI RF CRED PRIV LP',
#   'Última atualização': 'n/d',
#   'Valor da cota': '143.66295914',
#   'Rentabilidade 12 meses': '14,28%'},
#  {'CNPJ': '51.681.561/0001-34',
#   'Código ANBIMA': '729620',
#   'Patrimônio Líquido': 'R$ 27.941.303,42',
#   'Taxa de administração ao ano': '0,80%',
#   'Primeiro aporte': '25/09/2023',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Indexados',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Feeder',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Não se Aplica',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BB ASSET MANAGEMENT',
#   'Gestor': 'BB ASSET MANAGEMENT',
#   'Distribuidor': 'BANCO DO BRASIL',
#   'Custodiante': 'BANCO DO BRASIL',
#   'Controlador de ativos': 'BANCO DO BRASIL',
#   'Controlador de passivos': 'BANCO DO BRASIL',
#   'Taxa de administração máxima ao ano': '1,00%',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 0,01',
#   'Aplicação adicional mínima': 'R$ 0,01',
#   'Prazo para emissão de cotas em dias': '0',
#   'Prazo para pagamento do resgate em dias': '2',
#   'Prazo para conversão do resgate em dias': '0',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'R$ 0,01',
#   'Saldo mínimo aplicado': 'R$ 0,01',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/729620',
#   'Fundo': 'BB AÇÕES DIVERSIDADE IS FC FIA',
#   'Arquivo': 'BB AÇÕES DIVERSIDADE IS FC FIA',
#   'Última atualização': 'n/d',
#   'Valor da cota': '1.102581568',
#   'Rentabilidade 12 meses': 'n/d'},
#  {'CNPJ': '53.191.473/0001-80',
#   'Código ANBIMA': '748285',
#   'Patrimônio Líquido': 'R$ 382.475.411,44',
#   'Taxa de administração ao ano': '0,00%',
#   'Primeiro aporte': '26/02/2024',
#   'Classe ANBIMA': 'Renda Fixa',
#   'Tipo ANBIMA': 'Renda Fixa Duração Livre Crédito Livre',
#   'Classe CVM': 'Renda Fixa',
#   'Sub Classe CVM': 'Crédito Privado',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Espelho',
#   'Benchmark': 'CDI',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Até 20 %',
#   'Credito privado': 'Sim',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BB ASSET MANAGEMENT',
#   'Gestor': 'BB ASSET MANAGEMENT',
#   'Distribuidor': 'BANCO DO BRASIL',
#   'Custodiante': 'BANCO DO BRASIL',
#   'Controlador de ativos': 'BANCO DO BRASIL',
#   'Controlador de passivos': 'BANCO DO BRASIL',
#   'Taxa de administração máxima ao ano': '1,50%',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se Aplica',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 100,00',
#   'Aplicação adicional mínima': 'R$ 100,00',
#   'Prazo para emissão de cotas em dias': '0',
#   'Prazo para pagamento do resgate em dias': '6',
#   'Prazo para conversão do resgate em dias': '5',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'R$ 100,00',
#   'Saldo mínimo aplicado': 'R$ 100,00',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/748285',
#   'Fundo': 'BB ESPELHO JGP EQUILÍBRIO FUNDO DE INVESTIMENTO EM COTAS DE FUNDO DE INVESTIMENTO FINANCEIRO IS RENDA FIXA CRÉDITO PRIVADO LONGO PRAZO RESP LIMITADA',
#   'Arquivo': 'BB ESPELHO JGP EQUILÍBRIO FUNDO DE INVESTIMENTO EM COTAS DE FUNDO DE INVESTIMENTO FINANCEIRO IS RENDA FIXA CRÉDITO PRIVADO LONGO PRAZO RESP LIMITADA',
#   'Última atualização': 'n/d',
#   'Valor da cota': '1.010315433',
#   'Rentabilidade 12 meses': 'n/d'},
#  {'CNPJ': '37.565.324/0001-87',
#   'Código ANBIMA': '548340',
#   'ISIN': 'BR04ZNCTF002',
#   'Patrimônio Líquido': 'R$ 57.258.136,01',
#   'Taxa de administração ao ano': 'n/d',
#   'Primeiro aporte': '07/08/2020',
#   'Classe ANBIMA': 'Multimercados',
#   'Tipo ANBIMA': 'Multimercados Invest. no Exterior',
#   'Classe CVM': 'Multimercados',
#   'Sub Classe CVM': 'Crédito Privado',
#   'Fundo ESG': 'Não',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Não se aplica',
#   'Benchmark': 'OUTROS',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': '> 67%',
#   'Credito privado': 'Sim',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Inv. Qualificado',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Longo Prazo',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BRADESCO',
#   'Gestor': 'BRAM BRADESCO ASSET MANAGEMENT SA DTVM',
#   'Distribuidor': 'BRADESCO',
#   'Custodiante': 'BRADESCO',
#   'Controlador de ativos': 'BRADESCO',
#   'Controlador de passivos': 'n/d',
#   'Taxa de administração máxima ao ano': 'Percentual',
#   'Unidade da taxa de administração': 'Sim',
#   'Taxa composta': 'Não',
#   'Cobra taxa performance': 'n/d',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'Não se Aplica',
#   'Taxa de entrada': 'Não se Aplica',
#   'Taxa de saída': 'Não se aplica',
#   'Regra da taxa de saída': 'n/d',
#   'Aplicação inicial mínima': 'n/d',
#   'Aplicação adicional mínima': '0',
#   'Prazo para emissão de cotas em dias': '30',
#   'Prazo para pagamento do resgate em dias': '28',
#   'Prazo para conversão do resgate em dias': 'n/d',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'n/d',
#   'Saldo mínimo aplicado': 'n/d',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/548340',
#   'Fundo': 'BRAD IS MUL USD FC FI MULT CRED PRIV IE',
#   'Arquivo': 'BRAD IS MUL USD FC FI MULT CRED PRIV IE',
#   'Última atualização': 'n/d',
#   'Valor da cota': '0.9978369',
#   'Rentabilidade 12 meses': '1,13%'},
#  {'CNPJ': '31.937.303/0001-69',
#   'Código ANBIMA': '001082',
#   'ISIN': 'BRBRBFCTF007',
#   'Patrimônio Líquido': 'R$ 1.946.679,63',
#   'Taxa de administração ao ano': '2,50%',
#   'Primeiro aporte': '02/01/1980',
#   'Classe ANBIMA': 'Ações',
#   'Tipo ANBIMA': 'Ações Indexados',
#   'Classe CVM': 'Ações',
#   'Sub Classe CVM': 'Não se Aplica',
#   'Fundo ESG': 'Sim',
#   'Composição do fundo': 'FIC',
#   'Fundo Master': 'Não',
#   'Estrutura de gestão': 'Feeder',
#   'Benchmark': 'IGCT',
#   'Foco de atuação': 'Não se aplica',
#   'Investimento no exterior': 'Não se Aplica',
#   'Credito privado': 'Não',
#   'Tipo de investidor': 'Não Há Restrição',
#   'Característica do investidor': 'Geral',
#   'Cota de abertura': 'Não',
#   'Fundo permite alavancagem': 'Não',
#   'Aberto estatutariamente': 'Sim',
#   'Tributação Alvo': 'Renda Variável',
#   'Permite aplicação automática': 'Não',
#   'Moeda': 'R$',
#   'Administrador': 'BRB DTVM',
#   'Gestor': 'PLURAL INVESTIMENTOS GESTAO DE REC LTDA',
#   'Distribuidor': 'BRB S.A.',
#   'Custodiante': 'BRB S.A.',
#   'Controlador de ativos': 'BRB S.A.',
#   'Controlador de passivos': 'BRB S.A.',
#   'Taxa de administração máxima ao ano': '2,50%',
#   'Unidade da taxa de administração': 'Percentual',
#   'Taxa composta': 'Sim',
#   'Cobra taxa performance': 'Não',
#   'Regras da taxa de performance (não padronizada)': 'n/d',
#   'Período de cobrança da taxa de performance': 'n/d',
#   'Taxa de entrada': 'n/d',
#   'Taxa de saída': 'n/d',
#   'Regra da taxa de saída': 'Não se aplica',
#   'Aplicação inicial mínima': 'R$ 500,00',
#   'Aplicação adicional mínima': 'R$ 250,00',
#   'Prazo para emissão de cotas em dias': '0',
#   'Prazo para pagamento do resgate em dias': '4',
#   'Prazo para conversão do resgate em dias': '1',
#   'Carência inicial para 1º resgate em dias': 'n/d',
#   'Carência cíclica em dias (tempo entre resgates)': 'n/d',
#   'Resgate mínimo': 'R$ 250,00',
#   'Saldo mínimo aplicado': 'R$ 250,00',
#   'Status em 01/04/2024': 'ATIVO',
#   'URL do Fundo': 'https://data.anbima.com.br/fundos/001082',
#   'Fundo': 'BRB INVESTIMENTO SUSTENTÁVEL FIC FIA RESPONSABILIDADE LIMITADA',
#   'Arquivo': 'BRB INVESTIMENTO SUSTENTÁVEL FIC FIA RESPONSABILIDADE LIMITADA',
#   'Última atualização': 'n/d',
#   'Valor da cota': '56.56803694',
#   'Rentabilidade 12 meses': '29,76%'}]

# %%
## Salva metadados em arquivo json. 
import json
with open('../data/json/metadados.json', 'w', encoding='utf-8') as f:
        json.dump(metadados, f, ensure_ascii=False, indent=4)
